# %%
from packaging import version

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import tensorboard as tb
import tensorflow as tf
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os
import numpy as np

# %%
major_ver, minor_ver, _ = version.parse(tb.__version__).release
assert major_ver >= 2 and minor_ver >= 3, \
    "This notebook requires TensorBoard 2.3 or later."
print("TensorBoard version: ", tb.__version__)
# Out:
# TensorBoard version:  2.7.0

# %%
env_list = ['atari_seaquest', 'atari_enduro', 'atari_pong']
agent_list = ['agent_1', 'agent_2', 'agent_3', 'agent_4', 'patch_size_1', 'patch_size_4', 'patch_size_16']
seed_list = ['1', '2', '3']
metric_list = ['scalars/train_return', 'scalars/eval_resample_jitter_inter_avg_return', 'scalars/eval_resample_jitter_extra_avg_return', 'scalars/eval_rgb_avg_return']
dir_path = '../split_dreamer_logs/logs/'
def extract_score():
    score_array = np.zeros((len(env_list), len(agent_list), len(metric_list), len(seed_list)))
    for env_idx, env in enumerate(env_list):
        for agent_idx, agent in enumerate(agent_list):
            for metric_idx, metric in enumerate(metric_list):
                for seed_idx, seed in enumerate(seed_list):

                    file_path = os.path.join(dir_path, env, agent, seed)
                    print(file_path)
                    # read from summary writer
                    event_acc = EventAccumulator(file_path, size_guidance={'tensors': 0})
                    event_acc.Reload()
                    w, s, t = event_acc.Tensors(metric)[-1]
                    score_array[env_idx, agent_idx, metric_idx, seed_idx] = tf.make_ndarray(t)
    return score_array
#                 dataframe = pd.DataFrame([(w, s, tf.make_ndarray(t)) for w, s, t in event_acc.Tensors('scalars/eval_resample_jitter_extra_avg_return')],
#                 columns=['wall_time', 'step', 'tensor'])
# Save
score_array = extract_score()
np.save(os.path.join(dir_path, "scores.npy"), score_array)
# Load
score_array = np.load(os.path.join(dir_path, "scores.npy"))
# Out:
# ../../split_dreamer_logs/logs/atari_seaquest/agent_1/1
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/directory_watcher.py in Load(self)
#      87         try:
# ---> 88             for event in self._LoadInternal():
#      89                 yield event
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _LoadInternal(self)
#     109         if not self._loader:
# --> 110             self._InitializeLoader()
#     111
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _InitializeLoader(self)
#     172     def _InitializeLoader(self):
# --> 173         path = self._GetNextPath()
#     174         if path:
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _GetNextPath(self)
#     209             path
# --> 210             for path in io_wrapper.ListDirectoryAbsolute(self._directory)
#     211             if self._path_filter(path)
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/io_wrapper.py in ListDirectoryAbsolute(directory)
#      77     return (
# ---> 78         os.path.join(directory, path) for path in tf.io.gfile.listdir(directory)
#      79     )
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py in list_directory_v2(path)
#     696         op=None,
# --> 697         message="Could not find directory {}".format(path))
#     698
#
# NotFoundError: Could not find directory ../../split_dreamer_logs/logs/atari_seaquest/agent_1/1
#
# During handling of the above exception, another exception occurred:
#
# DirectoryDeletedError                     Traceback (most recent call last)
# <ipython-input-6-16feded15e59> in <module>
#      22 #                 columns=['wall_time', 'step', 'tensor'])
#      23 # Save
# ---> 24 score_array = extract_score()
#      25 np.save(os.path.join(dir_path, "scores.npy"), score_array)
#      26 # Load
#
# <ipython-input-6-16feded15e59> in extract_score()
#      15                     # read from summary writer
#      16                     event_acc = EventAccumulator(file_path, size_guidance={'tensors': 0})
# ---> 17                     event_acc.Reload()
#      18                     w, s, t = event_acc.Tensors(metric)[-1]
#      19                     score_array[env_idx, agent_idx, metric_idx, seed_idx] = tf.make_ndarray(t)
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/event_accumulator.py in Reload(self)
#     244         """
#     245         with self._generator_mutex:
# --> 246             for event in self._generator.Load():
#     247                 self._ProcessEvent(event)
#     248         return self
#
# ~/miniconda3/envs/dreamer/lib/python3.7/site-packages/tensorboard/backend/event_processing/directory_watcher.py in Load(self)
#      92                 raise DirectoryDeletedError(
#      93                     "Directory %s has been permanently deleted"
# ---> 94                     % self._directory
#      95                 )
#      96
#
# DirectoryDeletedError: Directory ../../split_dreamer_logs/logs/atari_seaquest/agent_1/1 has been permanently deleted

# %%
score_mean = np.int_(list(np.mean(score_array, axis = 3)))
score_std = np.int_(list(np.std(score_array, axis = 3)))

# %%
print(score_mean[1,:,:].shape)
# Out:
# (7, 4)

# %%
columns_name = ['inter_avg_return', 'extra_avg_return', 'rgb_avg_return']
rows_name = ['Baseline', 'Upper Bound (Trained with full range jittering)', 'SPLIT Patch Size: 8' , 'SPLIT Patch Size: 8 & Fixed Beta' , 'SPLIT Patch Size: 1' , 'SPLIT Patch Size: 4', 'SPLIT Patch Size: 16']
seaquest_returns = pd.DataFrame(score_mean[0, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)
enduro_returns = pd.DataFrame(score_mean[1, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)
pong_returns = pd.DataFrame(score_mean[2, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)

seaquest_returns_std = pd.DataFrame(score_std[0, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)
enduro_returns_std = pd.DataFrame(score_std[1, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)
pong_returns_std = pd.DataFrame(score_std[2, :, 1:], 
                                 columns=columns_name, 
                                index=rows_name)

# %%
seaquest_returns.style.highlight_max(color='red',axis=0)
# Seaquest Returns
# Out:
# <style type="text/css">
# #T_9d414_row1_col1, #T_9d414_row4_col0, #T_9d414_row4_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_9d414_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >inter_avg_return</th>
#       <th class="col_heading level0 col1" >extra_avg_return</th>
#       <th class="col_heading level0 col2" >rgb_avg_return</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d414_level0_row0" class="row_heading level0 row0" >Baseline</th>
#       <td id="T_9d414_row0_col0" class="data row0 col0" >4160</td>
#       <td id="T_9d414_row0_col1" class="data row0 col1" >110</td>
#       <td id="T_9d414_row0_col2" class="data row0 col2" >3905</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row1" class="row_heading level0 row1" >Upper Bound (Trained with full range jittering)</th>
#       <td id="T_9d414_row1_col0" class="data row1 col0" >2576</td>
#       <td id="T_9d414_row1_col1" class="data row1 col1" >2468</td>
#       <td id="T_9d414_row1_col2" class="data row1 col2" >2746</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row2" class="row_heading level0 row2" >SPLIT Patch Size: 8</th>
#       <td id="T_9d414_row2_col0" class="data row2 col0" >8184</td>
#       <td id="T_9d414_row2_col1" class="data row2 col1" >293</td>
#       <td id="T_9d414_row2_col2" class="data row2 col2" >8878</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row3" class="row_heading level0 row3" >SPLIT Patch Size: 8 & Fixed Beta</th>
#       <td id="T_9d414_row3_col0" class="data row3 col0" >4655</td>
#       <td id="T_9d414_row3_col1" class="data row3 col1" >175</td>
#       <td id="T_9d414_row3_col2" class="data row3 col2" >4720</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row4" class="row_heading level0 row4" >SPLIT Patch Size: 1</th>
#       <td id="T_9d414_row4_col0" class="data row4 col0" >13965</td>
#       <td id="T_9d414_row4_col1" class="data row4 col1" >1525</td>
#       <td id="T_9d414_row4_col2" class="data row4 col2" >13899</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row5" class="row_heading level0 row5" >SPLIT Patch Size: 4</th>
#       <td id="T_9d414_row5_col0" class="data row5 col0" >6598</td>
#       <td id="T_9d414_row5_col1" class="data row5 col1" >539</td>
#       <td id="T_9d414_row5_col2" class="data row5 col2" >6863</td>
#     </tr>
#     <tr>
#       <th id="T_9d414_level0_row6" class="row_heading level0 row6" >SPLIT Patch Size: 16</th>
#       <td id="T_9d414_row6_col0" class="data row6 col0" >8598</td>
#       <td id="T_9d414_row6_col1" class="data row6 col1" >988</td>
#       <td id="T_9d414_row6_col2" class="data row6 col2" >8226</td>
#     </tr>
#   </tbody>
# </table>

# %%
seaquest_returns_std
# Out:
#                                                  inter_avg_return  \
# Baseline                                                     1412
# Upper Bound (Trained with full range jittering)               725
# SPLIT Patch Size: 8                                          1814
# SPLIT Patch Size: 8 & Fixed Beta                             2179
# SPLIT Patch Size: 1                                         12490
# SPLIT Patch Size: 4                                           899
# SPLIT Patch Size: 16                                         1394
#
#                                                  extra_avg_return  \
# Baseline                                                       30
# Upper Bound (Trained with full range jittering)               673
# SPLIT Patch Size: 8                                            62
# SPLIT Patch Size: 8 & Fixed Beta                              122
# SPLIT Patch Size: 1                                           535
# SPLIT Patch Size: 4                                           119
# SPLIT Patch Size: 16                                          400
#
#                                                  rgb_avg_return
# Baseline                                                   1463
# Upper Bound (Trained with full range jittering)             756
# SPLIT Patch Size: 8                                        2059
# SPLIT Patch Size: 8 & Fixed Beta                           2189
# SPLIT Patch Size: 1                                       11696
# SPLIT Patch Size: 4                                        1030
# SPLIT Patch Size: 16                                        642

# %%
enduro_returns.style.highlight_max(color='red',axis=0)
# Enduro Returns
# Out:
# <style type="text/css">
# #T_08fae_row1_col1, #T_08fae_row6_col0, #T_08fae_row6_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_08fae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >inter_avg_return</th>
#       <th class="col_heading level0 col1" >extra_avg_return</th>
#       <th class="col_heading level0 col2" >rgb_avg_return</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08fae_level0_row0" class="row_heading level0 row0" >Baseline</th>
#       <td id="T_08fae_row0_col0" class="data row0 col0" >1490</td>
#       <td id="T_08fae_row0_col1" class="data row0 col1" >180</td>
#       <td id="T_08fae_row0_col2" class="data row0 col2" >1417</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row1" class="row_heading level0 row1" >Upper Bound (Trained with full range jittering)</th>
#       <td id="T_08fae_row1_col0" class="data row1 col0" >903</td>
#       <td id="T_08fae_row1_col1" class="data row1 col1" >730</td>
#       <td id="T_08fae_row1_col2" class="data row1 col2" >975</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row2" class="row_heading level0 row2" >SPLIT Patch Size: 8</th>
#       <td id="T_08fae_row2_col0" class="data row2 col0" >1476</td>
#       <td id="T_08fae_row2_col1" class="data row2 col1" >393</td>
#       <td id="T_08fae_row2_col2" class="data row2 col2" >1474</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row3" class="row_heading level0 row3" >SPLIT Patch Size: 8 & Fixed Beta</th>
#       <td id="T_08fae_row3_col0" class="data row3 col0" >1574</td>
#       <td id="T_08fae_row3_col1" class="data row3 col1" >248</td>
#       <td id="T_08fae_row3_col2" class="data row3 col2" >1476</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row4" class="row_heading level0 row4" >SPLIT Patch Size: 1</th>
#       <td id="T_08fae_row4_col0" class="data row4 col0" >1788</td>
#       <td id="T_08fae_row4_col1" class="data row4 col1" >632</td>
#       <td id="T_08fae_row4_col2" class="data row4 col2" >1956</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row5" class="row_heading level0 row5" >SPLIT Patch Size: 4</th>
#       <td id="T_08fae_row5_col0" class="data row5 col0" >1454</td>
#       <td id="T_08fae_row5_col1" class="data row5 col1" >438</td>
#       <td id="T_08fae_row5_col2" class="data row5 col2" >1681</td>
#     </tr>
#     <tr>
#       <th id="T_08fae_level0_row6" class="row_heading level0 row6" >SPLIT Patch Size: 16</th>
#       <td id="T_08fae_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_08fae_row6_col1" class="data row6 col1" >665</td>
#       <td id="T_08fae_row6_col2" class="data row6 col2" >2099</td>
#     </tr>
#   </tbody>
# </table>

# %%
enduro_returns_std
# Out:
#                                                  inter_avg_return  \
# Baseline                                                      155
# Upper Bound (Trained with full range jittering)               166
# SPLIT Patch Size: 8                                           239
# SPLIT Patch Size: 8 & Fixed Beta                              394
# SPLIT Patch Size: 1                                            30
# SPLIT Patch Size: 4                                            67
# SPLIT Patch Size: 16                                           81
#
#                                                  extra_avg_return  \
# Baseline                                                       39
# Upper Bound (Trained with full range jittering)               109
# SPLIT Patch Size: 8                                           103
# SPLIT Patch Size: 8 & Fixed Beta                               52
# SPLIT Patch Size: 1                                            89
# SPLIT Patch Size: 4                                           104
# SPLIT Patch Size: 16                                          172
#
#                                                  rgb_avg_return
# Baseline                                                    168
# Upper Bound (Trained with full range jittering)              99
# SPLIT Patch Size: 8                                         133
# SPLIT Patch Size: 8 & Fixed Beta                            545
# SPLIT Patch Size: 1                                          42
# SPLIT Patch Size: 4                                         233
# SPLIT Patch Size: 16                                         57

# %%
pong_returns.style.highlight_max(color='red',axis=0)
# Pong Returns
# Out:
# <style type="text/css">
# #T_d1bf7_row0_col0, #T_d1bf7_row0_col2, #T_d1bf7_row1_col1, #T_d1bf7_row6_col0, #T_d1bf7_row6_col1, #T_d1bf7_row6_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_d1bf7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >inter_avg_return</th>
#       <th class="col_heading level0 col1" >extra_avg_return</th>
#       <th class="col_heading level0 col2" >rgb_avg_return</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1bf7_level0_row0" class="row_heading level0 row0" >Baseline</th>
#       <td id="T_d1bf7_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_d1bf7_row0_col1" class="data row0 col1" >-14</td>
#       <td id="T_d1bf7_row0_col2" class="data row0 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row1" class="row_heading level0 row1" >Upper Bound (Trained with full range jittering)</th>
#       <td id="T_d1bf7_row1_col0" class="data row1 col0" >17</td>
#       <td id="T_d1bf7_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_d1bf7_row1_col2" class="data row1 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row2" class="row_heading level0 row2" >SPLIT Patch Size: 8</th>
#       <td id="T_d1bf7_row2_col0" class="data row2 col0" >17</td>
#       <td id="T_d1bf7_row2_col1" class="data row2 col1" >6</td>
#       <td id="T_d1bf7_row2_col2" class="data row2 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row3" class="row_heading level0 row3" >SPLIT Patch Size: 8 & Fixed Beta</th>
#       <td id="T_d1bf7_row3_col0" class="data row3 col0" >17</td>
#       <td id="T_d1bf7_row3_col1" class="data row3 col1" >-9</td>
#       <td id="T_d1bf7_row3_col2" class="data row3 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row4" class="row_heading level0 row4" >SPLIT Patch Size: 1</th>
#       <td id="T_d1bf7_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_d1bf7_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_d1bf7_row4_col2" class="data row4 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row5" class="row_heading level0 row5" >SPLIT Patch Size: 4</th>
#       <td id="T_d1bf7_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_d1bf7_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_d1bf7_row5_col2" class="data row5 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d1bf7_level0_row6" class="row_heading level0 row6" >SPLIT Patch Size: 16</th>
#       <td id="T_d1bf7_row6_col0" class="data row6 col0" >19</td>
#       <td id="T_d1bf7_row6_col1" class="data row6 col1" >15</td>
#       <td id="T_d1bf7_row6_col2" class="data row6 col2" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
pong_returns_std
# Out:
#                                                  inter_avg_return  \
# Baseline                                                        0
# Upper Bound (Trained with full range jittering)                 0
# SPLIT Patch Size: 8                                             0
# SPLIT Patch Size: 8 & Fixed Beta                                0
# SPLIT Patch Size: 1                                             1
# SPLIT Patch Size: 4                                            11
# SPLIT Patch Size: 16                                            0
#
#                                                  extra_avg_return  \
# Baseline                                                        4
# Upper Bound (Trained with full range jittering)                 1
# SPLIT Patch Size: 8                                             3
# SPLIT Patch Size: 8 & Fixed Beta                                5
# SPLIT Patch Size: 1                                            11
# SPLIT Patch Size: 4                                            10
# SPLIT Patch Size: 16                                            2
#
#                                                  rgb_avg_return
# Baseline                                                      0
# Upper Bound (Trained with full range jittering)               1
# SPLIT Patch Size: 8                                           0
# SPLIT Patch Size: 8 & Fixed Beta                              0
# SPLIT Patch Size: 1                                           1
# SPLIT Patch Size: 4                                          10
# SPLIT Patch Size: 16                                          0
